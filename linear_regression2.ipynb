# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\naruk\OneDrive\Desktop\diamonds.csv")

# %%
data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6               7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7               8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8               9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9              10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10             11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# ...

# %%
y=data["price"]

# %%
x=data

# %%
x=x.drop('price',axis=1)
x=x.drop("color",axis=1)
x=x.drop('cut',axis=1)

# %%
x=x.drop("clarity",axis=1)

# %%
x.shape
# Out:
# (53940, 7)

# %%
y.shape
# Out:
# (53940,)

# %%
import sklearn
from sklearn.linear_model import LinearRegression
x_train,x_test,y_train,y_test=sklearn.model_selection.train_test_split(x,y,test_size=0.2,random_state=5)

# %%
x_train.shape
# Out:
# (43152, 7)

# %%
x_test.shape
# Out:
# (10788, 7)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=model.predict(x_test)

# %%
mse=sklearn.metrics.mean_squared_error(y_pred,y_test)

# %%
print(mse)
# Out:
# 2234094.3356096097

# %%
plt.plot(y_test,y_pred,[y_test.min(),y_test.max()],[y_test.min(),y_test.max()])

# %%
plt.plot(y_test,y_pred,"g^",[y_test.min(),y_test.max()],[y_test.min(),y_test.max()])

# %%
data.cut[data.cut=="Fair"]=1
data.cut[data.cut=="Good"]=2
data.cut[data.cut=="Very Good"]=3
data.cut[data.cut=="Premium"]=4
data.cut[data.cut=="Ideal"]=1
# Out:
# C:\Users\naruk\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\naruk\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\naruk\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
plt.plot(data['clarity'],data['price'],'go')

# %%
data["clarity"].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
data.clarity[data.clarity=="SI2"]=1
data.clarity[data.clarity=="SI1"]=2
data.clarity[data.clarity=="VS1"]=3
data.clarity[data.clarity=="VS2"]=4
data.clarity[data.clarity=="VVS2"]=5
data.clarity[data.clarity=="VVS1"]=6
data.clarity[data.clarity=="I1"]=7
data.clarity[data.clarity=="IF"]=8
# Out:
# C:\Users\naruk\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\naruk\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\naruk\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
data=data.drop("color",axis=1)

# %%
data
# Out:
#        Unnamed: 0  carat cut clarity  depth  table  price     x     y     z
# 0               1   0.23   1       1   61.5   55.0    326  3.95  3.98  2.43
# 1               2   0.21   4       2   59.8   61.0    326  3.89  3.84  2.31
# 2               3   0.23   2       3   56.9   65.0    327  4.05  4.07  2.31
# 3               4   0.29   4       4   62.4   58.0    334  4.20  4.23  2.63
# 4               5   0.31   2       1   63.3   58.0    335  4.34  4.35  2.75
# 5               6   0.24   3       5   62.8   57.0    336  3.94  3.96  2.48
# 6               7   0.24   3       6   62.3   57.0    336  3.95  3.98  2.47
# 7               8   0.26   3       2   61.9   55.0    337  4.07  4.11  2.53
# 8               9   0.22   1       4   65.1   61.0    337  3.87  3.78  2.49
# 9              10   0.23   3       3   59.4   61.0    338  4.00  4.05  2.39
# 10             11   0.30   2       2   64.0   55.0    339  4.25  4.28  2.73
# ...

# %%
a=data.iloc[:,1:10]

# %%
y=a.price

# %%
x=a.drop("price",axis=1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
import sklearn
from sklearn.linear_model import LinearRegression
x_train,x_test,y_train,y_test=sklearn.model_selection.train_test_split(x,y,test_size=0.2,random_state=5)

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=model.predict(x_test)
mse=sklearn.metrics.mean_squared_error(y_pred,y_test)
print(mse)
# Out:
# 2035564.0378829923

# %%
plt.plot(y_test,y_pred,"go",[y_test.min(),y_test.max()],[y_test.min(),y_test.max()],"r--")
