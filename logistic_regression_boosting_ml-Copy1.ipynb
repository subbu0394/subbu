# %%
import pandas as pd

# %%
import sklearn
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\naruk\OneDrive\Desktop\LR_Cust Data.csv")

# %%
div=data.pop("Division.Name")

# %%
data['general']=(div=="General")*1.0
data['petite']=(div=="General Petite")*1.0

# %%
dep=data.pop("Department.Name")

# %%
data["dress"]=(dep=="Dresses")*1.0
data["jacket"]=(dep=="Jackets")*1.0

# %%
model=LogisticRegression(max_iter=1000)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn import ensemble

# %%
adaboost=ensemble.AdaBoostClassifier(base_estimator=model,n_estimators=400,learning_rate=1)

# %%
from sklearn.model_selection import train_test_split

# %%
y=data['Department.Name']

# %%
x=data.drop('Department.Name',axis=1)

# %%
x_train,x_test,y_train,y_test=sklearn.model_selection.train_test_split(x,y,test_size=0.2,random_state=5)

# %%
boost=adaboost.fit(x,y)
# Out:
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
boost.score(x_test,y_test)
# Out:
# 0.8610354223433242

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.score(x_test,y_test)
# Out:
# 0.9400544959128065

# %%
from sklearn.model_selection import cross_val_score

# %%
print(np.mean(cross_val_score(model,x,y,cv=20)))
# Out:
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\naruk\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...
